# %%
from equationgroup import *
from operationtree import *

# %%
# clean files
with open('grouptheorems.ard', 'w') as f:
    print(" cleaned")
# Out:
#  cleaned

# %%
from torch.utils.data import random_split

first, second, third, fourth, fifth = random_split(list(range(1000)), [200] * 5)
lists = [first, second, third, fourth, fifth]

for i, l in enumerate(lists):
    with open(f'group_equations/grouptheorems{i}.ard', 'w') as f:
        for i in range(200):
            n_types = random.randint(2, 15)
            bound_length = random.randint(2, 10)
            f.write(create_random_arend_group_proof(n_types, bound_length, i) + '\n\n')
